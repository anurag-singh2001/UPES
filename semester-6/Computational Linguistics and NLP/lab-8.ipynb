# %%
import pandas as pd

# %%
df=pd.read_csv('twitter.csv')
df
# Out:
#      Unnamed: 0                           _type  \
# 0             0  snscrape.modules.twitter.Tweet
# 1             1  snscrape.modules.twitter.Tweet
# 2             2  snscrape.modules.twitter.Tweet
# 3             3  snscrape.modules.twitter.Tweet
# 4             4  snscrape.modules.twitter.Tweet
# ..          ...                             ...
# 145         145  snscrape.modules.twitter.Tweet
# 146         146  snscrape.modules.twitter.Tweet
# 147         147  snscrape.modules.twitter.Tweet
# 148         148  snscrape.modules.twitter.Tweet
# 149         149  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/narendramodi/status/161740...
# 1    https://twitter.com/narendramodi/status/161736...
# 2    https://twitter.com/narendramodi/status/161735...
# 3    https://twitter.com/narendramodi/status/161717...
# 4    https://twitter.com/narendramodi/status/161717...
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-2c88cc3c97be> in <module>
# ----> 1 import nltk
#       2 nltk.download('punkt')
#       3 nltk.download('stopwords')
#       4 nltk.download('wordnet')
#       5 nltk.download('omw-1.4')
#
# ~\anaconda3\lib\site-packages\nltk\__init__.py in <module>
#     140 ###########################################################
#     141
# --> 142 from nltk.chunk import *
#     143 from nltk.classify import *
#     144 from nltk.inference import *
#
# ~\anaconda3\lib\site-packages\nltk\chunk\__init__.py in <module>
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (
#     159     ChunkScore,
#
# ~\anaconda3\lib\site-packages\nltk\chunk\api.py in <module>
#      11 ##//////////////////////////////////////////////////////
#      12
# ...
