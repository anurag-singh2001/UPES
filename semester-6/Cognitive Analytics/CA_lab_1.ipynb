# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
x = [random.randint(1, 100) for n in range(100)]
y = [random.randint(1, 100) for n in range(100)]
plt.scatter(x, y)
plt.show()

# %%
plt.plot([1,2,3,5,6], [1, 2, 3, 4, 6])
plt.show()

# %%
a=[1,2,3,4,5]
b=[63, 81, 52, 22, 37]
c=[17, 28, 72, 52, 32]
plt.stackplot(a,b,c)
# Out:
# [<matplotlib.collections.PolyCollection at 0x7f9cb0b01970>,
#  <matplotlib.collections.PolyCollection at 0x7f9cb0b01c70>]

# %%
a=[22,55,62,45,21,22,34,42,42,4,2,8]
b=[1,10,20,30,40,50]
plt.hist(a, b, rwidth=0.6)
# Out:
# (array([3., 0., 3., 1., 3.]),
#  array([ 1, 10, 20, 30, 40, 50]),
#  <a list of 5 Patch objects>)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()
